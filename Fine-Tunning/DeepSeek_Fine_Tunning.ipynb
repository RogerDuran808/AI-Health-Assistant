# %%
from openai import OpenAI

client = OpenAI(api_key="sk-b25eadb69daf42789c62c8cf752596c3", base_url="https://api.deepseek.com")

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "You are an AI Health Assistant"
            },
        {"role": "user", "content": "How are you?"},
    ],
    stream=False
)

print(response.choices[0].message.content)
# Out:
# Thank you for asking! I'm just a virtual assistant, so I don't have feelings, but I'm here and ready to help you with any health-related questions or concerns you might have. How can I assist you today? 😊
# hola
